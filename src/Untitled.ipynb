# %%
import json

with open('test.json', 'r') as f:
    t = json.load((f))

# %%
t['Human']
# Out:
# {'first names': ['Aria',
#   'Cassiel',
#   'Erelim',
#   'Galizur',
#   'Jael',
#   'Kael',
#   'Leraje',
#   'Muriel',
#   'Nahiri',
#   'Zariel'],
#  'last names': ['Angelheart',
#   'Dusksinger',
#   'Lightbringer',
#   'Radiantwing',
#   'Silversong',
#   'Starborn'],
#  'age': [15, '1d6'],
#  'height': [58, '2d4'],
#  'weight': [120, '2d6'],
#  'size': 'Medium',
#  'speed': 30,
#  'traits': ['Versatility'],
#  'languages': ['Elven',
#   'Draconic',
#   'Gnoll',
#   'Gnome',
#   'Goblin',
#   'Orc',
#   'Sylvan']}

# %%
for k,v in t.items():
    v['first names'] = [n.lower() for n in v['first names'] ] 

t['Catfolk']['some cool attr'] ='asdfaf'

# %%
class NamesParse():

    def move_names(self, t):
        self.first_names = []
        self.last_names = []
        for k, v in t.items():

            print(k)
            if 'first names' in v:
                f_names = v['first names']
                del v['first names']

            if 'last names' in v:
                l_names = v['last names']
                del v['last names']

            self.first_names += f_names
            self.last_names += l_names

    def make_new_json(self, f_path):
        j = {'first names': self.first_names,
            'last names': self.last_names}
        
        with open(f_path, 'w') as f:
            f.write(str(j))
            
    def

# %%
# Out:
# Human
# Aasimar
# Catfolk
# Dragonborn
# Dhampir
# Drow
# Duergar
# Elf
# Fetchling
# Goblin
# Gnome
# Halfling
# Dwarf
# Half-Elf
# Half-Orc
# Hobgoblin
# Ifrit
# Kitsune
# Kobold
# Orc
# Oread
# Ratfolk
# Sylph
# Tengu
# Tiefling
# Undine
# Wayang
# Loxophant
# D-ziriak
# Tortugan
# ['aria',
#  'cassiel',
#  'erelim',
#  'galizur',
#  'jael',
#  'kael',
#  'leraje',
#  'muriel',
#  'nahiri',
#  'zariel',
#  'aria',
#  'cassiel',
#  'erelim',
#  'galizur',
#  'jael',
#  'kael',
#  'leraje',
#  'muriel',
#  'nahiri',
#  'zariel',
#  'chavi',
#  'jaswinder',
#  'kaela',
#  'korin',
#  'liris',
#  'mazzy',
#  'nanali',
#  'rajni',
#  'sarene',
#  'zahra',
#  'agon',
#  'egon',
#  'sugissa',
#  'qixiris',
#  'nysriel',
#  'qicoria',
#  'phidalynn',
#  'wraxiris',
#  'orinn',
#  'yrsaadi',
#  'mathtuan',
#  'nysqorel',
#  'zenpora',
#  'wradalynn',
#  'aria',
#  'caius',
#  'damien',
#  'eira',
#  'felicity',
#  'gideon',
#  'hazel',
#  'isadora',
#  'kael',
#  'lilith',
#  'mariel',
#  'nero',
#  'octavia',
#  'phaedra',
#  'raven',
#  'serafina',
#  'theron',
#  'vesper',
#  'ara',
#  'briar',
#  'cora',
#  'dara',
#  'eilistraee',
#  'faelivrin',
#  'gwen',
#  'halan',
#  'inara',
#  'jhaelryn',
#  'kael',
#  'liriel',
#  'mizzrym',
#  'nimor',
#  'pharaun',
#  'quenthel',
#  'rilrae',
#  'solaufein',
#  'thalack',
#  'ulitree',
#  'aukanthi',
#  'baela',
#  'drogan',
#  'ervendio',
#  'girnyaga',
#  'harral',
#  'isar',
#  'jarnak',
#  'kurk',
#  'lurka',
#  'mivra',
#  'nathir',
#  'onar',
#  'pezock',
#  'quaralyn',
#  'rautha',
#  'sarzan',
#  'thorbrog',
#  'ulfe',
#  'vonkil',
#  'adran',
#  'aelar',
#  'aramil',
#  'arannis',
#  'aust',
#  'beiro',
#  'berrian',
#  'carric',
#  'enialis',
#  'erdan',
#  'erevan',
#  'galinndan',
#  'hadarai',
#  'heian',
#  'himo',
#  'immeral',
#  'ivellios',
#  'laucian',
#  'mindartis',
#  'paelias',
#  'peren',
#  'quarion',
#  'riardon',
#  'rolen',
#  'soveliss',
#  'thamior',
#  'tharivol',
#  'theren',
#  'varis',
#  'aria',
#  'darian',
#  'jax',
#  'kiera',
#  'miles',
#  'nisha',
#  'sable',
#  'ty',
#  'zora',
#  'gnash',
#  'vola',
#  'zibini',
#  'sneeg',
#  'reta',
#  'snick',
#  'tuff',
#  'kukka',
#  'drixi',
#  'puska',
#  'kippa',
#  'alston',
#  'bilbron',
#  'caramip',
#  'donella',
#  'euphemia',
#  'fijit',
#  'gimble',
#  'lintra',
#  'milba',
#  'podwig',
#  'sorrel',
#  'wrenn',
#  'alton',
#  'ander',
#  'cade',
#  'corrin',
#  'eldon',
#  'errich',
#  'finnan',
#  'garret',
#  'lindal',
#  'lyle',
#  'merric',
#  'milo',
#  'osborn',
#  'perrin',
#  'reed',
#  'roscoe',
#  'wellby',
#  'adrik',
#  'alberich',
#  'baern',
#  'barendd',
#  'brottor',
#  'bruenor',
#  'dain',
#  'darrak',
#  'delg',
#  'eberk',
#  'einkil',
#  'fargrim',
#  'flint',
#  'gardain',
#  'harbek',
#  'kildrak',
#  'morgran',
#  'orsik',
#  'oskar',
#  'rangrim',
#  'rurik',
#  'taklinn',
#  'thoradin',
#  'thorin',
#  'tordek',
#  'traubon',
#  'travok',
#  'ulfgar',
#  'veit',
#  'vondal',
#  'aramil',
#  'arin',
#  'darian',
#  'elaith',
#  'erevan',
#  'fintan',
#  'isilme',
#  'keyleth',
#  'lairelos',
#  'laucian',
#  'liriel',
#  'lothir',
#  'maiele',
#  'melarue',
#  'merethyl',
#  'mindartis',
#  'naiadryl',
#  'naivara',
#  'naralieth',
#  'sariel',
#  'sariele',
#  'selsharra',
#  'siannodel',
#  'silaqui',
#  'tathariel',
#  'tialith',
#  'vadania',
#  'zereni',
#  'dench',
#  'feng',
#  'gell',
#  'henk',
#  'holg',
#  'imsh',
#  'keth',
#  'krusk',
#  'ront',
#  'shump',
#  'thokk',
#  'aukan',
#  'denchu',
#  'gulk',
#  'kishkumen',
#  'kothar',
#  'krusk',
#  'mhurren',
#  'nord',
#  'sark',
#  'vargach',
#  'akakios',
#  'aster',
#  'dax',
#  'eryndor',
#  'ignatius',
#  'nemeia',
#  'razia',
#  'talibah',
#  'zara',
#  'akane',
#  'chie',
#  'etsuko',
#  'haruko',
#  'kaori',
#  'miki',
#  'natsuki',
#  'rina',
#  'yumi',
#  'yuna',
#  'dek',
#  'drog',
#  'gak',
#  'keg',
#  'kronk',
#  'nak',
#  'soot',
#  'tik',
#  'trog',
#  'zak',
#  'drogath',
#  'grommash',
#  'hakak',
#  'karguk',
#  'mazgak',
#  'tharag',
#  'uzguk',
#  'vorgoth',
#  'zogar',
#  'bof',
#  'dolgrin',
#  'fargas',
#  'gethen',
#  'grunyar',
#  'heng',
#  'kazmuk',
#  'olarra',
#  'tazgurt',
#  'torgoth',
#  'briko',
#  'chirp',
#  'flea',
#  'kip',
#  'nibble',
#  'picket',
#  'quick',
#  'ridge',
#  'scurry',
#  'zig',
#  'aeris',
#  'aria',
#  'caeli',
#  'kara',
#  'nila',
#  'ora',
#  'phoebe',
#  'thalia',
#  'zephyr',
#  'bishr',
#  'fumihiro',
#  'haruki',
#  'karasu',
#  'kenji',
#  'kenta',
#  'masaaki',
#  'rokuro',
#  'shiro',
#  'takeshi',
#  'akmenos',
#  'amnon',
#  'barakas',
#  'damakos',
#  'ekemon',
#  'iados',
#  'kairon',
#  'leucis',
#  'melech',
#  'mordai',
#  'morthos',
#  'pelaios',
#  'skamos',
#  'therai',
#  'akane',
#  'hama',
#  'haruka',
#  'hotaru',
#  'kaida',
#  'kaito',
#  'kana',
#  'mizuho',
#  'nami',
#  'rin',
#  'sora',
#  'ari',
#  'bren',
#  'fen',
#  'hak',
#  'jin',
#  'kai',
#  'rai',
#  'tae',
#  'umi',
#  'yan',
#  'chavi',
#  'jaswinder',
#  'kaela',
#  'korin',
#  'liris',
#  'mazzy',
#  'nanali',
#  'rajni',
#  'sarene',
#  'zahra',
#  'chavi',
#  'jaswinder',
#  'kaela',
#  'korin',
#  'liris',
#  'mazzy',
#  'nanali',
#  'rajni',
#  'sarene',
#  'zahra',
#  'chavi',
#  'jaswinder',
#  'kaela',
#  'korin',
#  'liris',
#  'mazzy',
#  'nanali',
#  'rajni',
#  'sarene',
#  'zahra']
